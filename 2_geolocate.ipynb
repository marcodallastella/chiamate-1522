# %%
import requests
import pandas as pd
import time
import random

# %%
def get_coordinates_from_osm(province):
    
    # Construct the URL for OSM Nominatim
    base_url = "https://nominatim.openstreetmap.org/search"
    
    # Parameters for the search
    params = {
        'q': f"{province}, Italia",
        'format': 'json',
        'limit': 1
    }
    
    # Headers to identify our application
    headers = {
        'User-Agent': 'ProvinceMapVisualization/1.0 (md3934@columbia.edu)',
        'Accept-Language': 'it-IT,it'
    }
    
    try:
        # Add random delay between 1-2 seconds
        time.sleep(1 + random.random())
        
        response = requests.get(base_url, params=params, headers=headers)
        
        if response.status_code == 200:
            data = response.json()
            if data:
                return float(data[0]['lat']), float(data[0]['lon'])
        return None
    except Exception as e:
        print(f"Error getting coordinates for {province}: {e}")
        return None

# %%
df = pd.read_csv('../processed_data/calls_clean.csv')
df.head()
# Out:
#    year  week        date  provincia  calls
# 0  2024     2  2024-01-21  Agrigento      1
# 1  2024     3  2024-01-28  Agrigento      3
# 2  2024     4  2024-02-04  Agrigento      4
# 3  2024     5  2024-02-11  Agrigento      1
# 4  2024     6  2024-02-18  Agrigento      4

# %%
unique_provinces = df['provincia'].unique()

# Create a dictionary to store coordinates
coords_dict = {}

# Get coordinates for each province
print("Getting coordinates for provinces...")
for province in unique_provinces:
    if province not in coords_dict:
        print(f"Processing {province}...")
        coords = get_coordinates_from_osm(province)
        if coords:
            coords_dict[province] = coords
            print(f"Found coordinates for {province}: {coords}")
        else:
            print(f"Could not find coordinates for {province}")
# Out:
# Getting coordinates for provinces...
# Processing Agrigento...
# Found coordinates for Agrigento: (37.3122991, 13.57465)
# Processing Alessandria...
# Found coordinates for Alessandria: (44.83495335, 8.745030418605868)
# Processing Ancona...
# Found coordinates for Ancona: (43.4801189, 13.218727943815642)
# Processing Arezzo...
# Found coordinates for Arezzo: (43.51714415, 11.763928194732205)
# Processing Ascoli Piceno...
# Found coordinates for Ascoli Piceno: (42.8834204, 13.539593040686007)
# Processing Asti...
# Found coordinates for Asti: (44.826012649999996, 8.202686328987273)
# Processing Avellino...
# Found coordinates for Avellino: (40.9965446, 15.1405690365004)
# Processing Bari...
# Found coordinates for Bari: (41.1257843, 16.8620293)
# Processing Barletta-Andria-Trani...
# Found coordinates for Barletta-Andria-Trani: (41.180172, 16.1466408)
# Processing Belluno...
# Found coordinates for Belluno: (46.2805407, 12.078913722504204)
# Processing Benevento...
# Found coordinates for Benevento: (41.2476307, 14.705705363146528)
# Processing Bergamo...
# Found coordinates for Bergamo: (45.756655699999996, 9.754219200862249)
# Processing Biella...
# Found coordinates for Biella: (45.5669538, 8.086912008297636)
# Processing Bologna...
# Found coordinates for Bologna: (44.4938203, 11.3426327)
# Processing Bolzano...
# Found coordinates for Bolzano: (46.655945450000004, 11.23021287087526)
# Processing Brescia...
# Found coordinates for Brescia: (45.77958045, 10.4258729694612)
# Processing Brindisi...
# Found coordinates for Brindisi: (40.63591975, 17.688443357842537)
# Processing Cagliari...
# Found coordinates for Cagliari: (39.2171994, 9.113311)
# Processing Caltanissetta...
# Found coordinates for Caltanissetta: (37.4899412, 14.0631618)
# Processing Campobasso...
# Found coordinates for Campobasso: (41.717264799999995, 14.826226697820019)
# Processing Caserta...
# Found coordinates for Caserta: (41.20351925, 14.116862382970815)
# Processing Catania...
# Found coordinates for Catania: (37.5023612, 15.0873718)
# Processing Catanzaro...
# Found coordinates for Catanzaro: (38.82996034999999, 16.43155687627833)
# Processing Chieti...
# Found coordinates for Chieti: (42.10269285, 14.41590530501923)
# Processing Como...
# Found coordinates for Como: (45.939475900000005, 9.149410132545793)
# Processing Cosenza...
# Found coordinates for Cosenza: (39.596685300000004, 16.333055599019605)
# Processing Cremona...
# Found coordinates for Cremona: (45.22086405, 10.037037979628856)
# Processing Crotone...
# Found coordinates for Crotone: (39.1873894, 16.87828188895307)
# Processing Cuneo...
# Found coordinates for Cuneo: (44.45807035, 7.558136691151624)
# Processing Enna...
# Found coordinates for Enna: (37.5667573, 14.2807473)
# Processing Fermo...
# Found coordinates for Fermo: (43.0922489, 13.638768067263769)
# Processing Ferrara...
# Found coordinates for Ferrara: (44.766764249999994, 11.827938995640167)
# Processing Firenze...
# Found coordinates for Firenze: (43.7697955, 11.2556404)
# Processing Foggia...
# Found coordinates for Foggia: (41.50281055, 15.452893911491383)
# Processing Forlì-Cesena...
# Found coordinates for Forlì-Cesena: (44.0227193, 12.0141036)
# Processing Frosinone...
# Found coordinates for Frosinone: (41.628546799999995, 13.57584977062367)
# Processing Genova...
# Found coordinates for Genova: (44.40726, 8.9338624)
# Processing Gorizia...
# Found coordinates for Gorizia: (45.9441278, 13.6252288)
# Processing Grosseto...
# Found coordinates for Grosseto: (42.7751102, 11.287804427628437)
# Processing Imperia...
# Found coordinates for Imperia: (43.95837525, 7.866742714674276)
# Processing Isernia...
# Found coordinates for Isernia: (41.64950915, 14.208061831039291)
# Processing La Spezia...
# Found coordinates for La Spezia: (44.23836595, 9.691232634547537)
# Processing L'Aquila...
# Found coordinates for L'Aquila: (42.1368853, 13.610341022538911)
# Processing Latina...
# Found coordinates for Latina: (41.45952605, 13.012591212188894)
# Processing Lecce...
# Found coordinates for Lecce: (40.152217300000004, 18.2260628338229)
# Processing Lecco...
# Found coordinates for Lecco: (45.9005485, 9.41202482143963)
# Processing Livorno...
# Found coordinates for Livorno: (42.7902379, 10.340223929577242)
# Processing Lodi...
# Found coordinates for Lodi: (45.2613104, 9.491678060021837)
# Processing Lucca...
# Found coordinates for Lucca: (44.017763900000006, 10.454430026192636)
# Processing Macerata...
# Found coordinates for Macerata: (43.15297805, 13.150882217502017)
# Processing Mantova...
# Found coordinates for Mantova: (45.1692628, 10.670836515673878)
# Processing Massa-Carrara...
# Found coordinates for Massa-Carrara: (44.2131486, 10.0525615)
# Processing Matera...
# Found coordinates for Matera: (40.447641899999994, 16.47357384028852)
# Processing Messina...
# Found coordinates for Messina: (38.1937571, 15.5542082)
# Processing Milano...
# Found coordinates for Milano: (45.4641943, 9.1896346)
# Processing Modena...
# Found coordinates for Modena: (44.5384728, 10.935960870530739)
# Processing Monza e della Brianza...
# Found coordinates for Monza e della Brianza: (45.6395418, 9.278830418070044)
# Processing Napoli...
# Found coordinates for Napoli: (40.8358846, 14.2487679)
# Processing Novara...
# Found coordinates for Novara: (45.584250049999994, 8.545996970894572)
# Processing Nuoro...
# Found coordinates for Nuoro: (40.12765935, 9.342383344552438)
# Processing Olbia-Tempio...
# Found coordinates for Olbia-Tempio: (40.9253328, 9.506737539865965)
# Processing Oristano...
# Found coordinates for Oristano: (40.02656765, 8.679641647435716)
# Processing Padova...
# Found coordinates for Padova: (45.391408, 11.805848677115883)
# Processing Palermo...
# Found coordinates for Palermo: (38.1112268, 13.3524434)
# Processing Parma...
# Found coordinates for Parma: (44.6952006, 10.097986896904466)
# Processing Pavia...
# Found coordinates for Pavia: (45.036854649999995, 9.137825082826026)
# Processing Perugia...
# Found coordinates for Perugia: (43.1070321, 12.402996209906487)
# Processing Pesaro e Urbino...
# Found coordinates for Pesaro e Urbino: (43.694112700000005, 12.701443660480004)
# Processing Pescara...
# Found coordinates for Pescara: (42.3102619, 13.95759010584892)
# Processing Piacenza...
# Found coordinates for Piacenza: (44.8476352, 9.666531257696896)
# Processing Pisa...
# Found coordinates for Pisa: (43.4714722, 10.679791173704576)
# Processing Pistoia...
# Found coordinates for Pistoia: (43.9740957, 10.868708114044026)
# Processing Pordenone...
# Found coordinates for Pordenone: (45.9562503, 12.6597197)
# Processing Potenza...
# Found coordinates for Potenza: (40.51731195, 15.821608824871046)
# Processing Prato...
# Found coordinates for Prato: (43.935718050000006, 11.09414726770089)
# Processing Ragusa...
# Found coordinates for Ragusa: (36.9256833, 14.7307456)
# Processing Ravenna...
# Found coordinates for Ravenna: (44.364060699999996, 12.059009490863945)
# Processing Reggio Calabria...
# Found coordinates for Reggio Calabria: (38.1035389, 15.6397556)
# Processing Reggio nell'Emilia...
# Found coordinates for Reggio nell'Emilia: (44.6086674, 10.594066675914796)
# Processing Rieti...
# Found coordinates for Rieti: (42.41473635, 12.885888076510067)
# Processing Rimini...
# Found coordinates for Rimini: (43.946543250000005, 12.630749019254939)
# Processing Roma...
# Found coordinates for Roma: (41.8933203, 12.4829321)
# Processing Rovigo...
# Found coordinates for Rovigo: (44.9777098, 12.272683528362364)
# Processing Salerno...
# Found coordinates for Salerno: (40.419441649999996, 15.310608468834516)
# Processing Sassari...
# Found coordinates for Sassari: (40.7234746, 8.5612674)
# Processing Savona...
# Found coordinates for Savona: (44.2334238, 8.252572737021062)
# Processing Siena...
# Found coordinates for Siena: (43.167205949999996, 11.467561040475552)
# Processing Siracusa...
# Found coordinates for Siracusa: (37.0646139, 15.2907196)
# Processing Sondrio...
# Found coordinates for Sondrio: (46.32336235, 10.258413671017703)
# Processing Sud Sardegna...
# Found coordinates for Sud Sardegna: (39.5040428, 8.9895602)
# Processing Taranto...
# Found coordinates for Taranto: (40.54881555, 17.08058012454743)
# Processing Teramo...
# Found coordinates for Teramo: (42.65811795, 13.69787458752063)
# Processing Terni...
# Found coordinates for Terni: (42.6539486, 12.439652829139407)
# Processing Torino...
# Found coordinates for Torino: (45.0677551, 7.6824892)
# Processing Trapani...
# Found coordinates for Trapani: (38.0173961, 12.5160225)
# Processing Trento...
# Found coordinates for Trento: (46.1029536, 11.12974249416882)
# Processing Treviso...
# Found coordinates for Treviso: (45.806691349999994, 12.206315763116372)
# Processing Trieste...
# Found coordinates for Trieste: (45.6496485, 13.7772781)
# Processing Udine...
# Found coordinates for Udine: (46.0634632, 13.2358377)
# Processing Valle d'Aosta...
# Found coordinates for Valle d'Aosta: (45.730099, 7.387426)
# Processing Varese...
# Found coordinates for Varese: (45.839720299999996, 8.754133838056571)
# Processing Venezia...
# Found coordinates for Venezia: (45.4371908, 12.3345898)
# Processing Verbano-Cusio-Ossola...
# Found coordinates for Verbano-Cusio-Ossola: (46.115575500000006, 8.383596697318476)
# Processing Vercelli...
# Found coordinates for Vercelli: (45.55538265, 8.346283678327271)
# Processing Verona...
# Found coordinates for Verona: (45.442497700000004, 10.985737689444763)
# Processing Vibo Valentia...
# Found coordinates for Vibo Valentia: (38.6266556, 16.098693458946357)
# Processing Vicenza...
# Found coordinates for Vicenza: (45.63485905, 11.40635425660249)
# Processing Viterbo...
# Found coordinates for Viterbo: (42.492952200000005, 11.948813551650236)
# Processing missing...
# Found coordinates for missing: (46.6641917, 11.4449242)
# Processing Aosta...
# Found coordinates for Aosta: (45.7370885, 7.3196649)
# Processing Carbonia-Iglesias...
# Found coordinates for Carbonia-Iglesias: (39.3074849, 8.540339543772328)
# Processing Forlì Cesena...
# Found coordinates for Forlì Cesena: (44.0227193, 12.0141036)
# Processing Medio Campidano...
# Found coordinates for Medio Campidano: (39.49365245, 8.765051979771284)
# Processing Pesaro Urbino...
# Found coordinates for Pesaro Urbino: (43.694112700000005, 12.701443660480004)
# Processing Reggio Emilia...
# Found coordinates for Reggio Emilia: (44.6086674, 10.594066675914796)
# Processing Ogliastra...
# Found coordinates for Ogliastra: (39.9705359, 9.6678107)

# %%
# Add coordinates to DataFrame
df['latitude'] = df['provincia'].map(lambda x: coords_dict.get(x)[0] if coords_dict.get(x) else None)
df['longitude'] = df['provincia'].map(lambda x: coords_dict.get(x)[1] if coords_dict.get(x) else None)

df.to_csv('../processed_data/calls_latlon.csv', index=False)

# %% [markdown]
# ### Some corrections are needed

# %%
df = pd.read_csv('../processed_data/calls_latlon.csv')

# %%
# Make corrections
corrections = {
    'missing': ('', ''),
    'ForlÃ¬-Cesena': (44.22238317778976, 12.040962409019011),
    "Valle d'Aosta/VallÃ©e d'Aoste": (45.733184284216605, 7.298274149320562),
    "Livorno": (43.54673711579884, 10.312234337127085), #For some reason the provincia of Livorno was being located in the Isola d'Elba
}

# %%
# Apply corrections
for province, (lat, lon) in corrections.items():
    mask = df['provincia'] == province
    df.loc[mask, 'latitude'] = lat
    df.loc[mask, 'longitude'] = lon

df.to_csv('../processed_data/calls_latlon.csv', index=False)

# Verify the changes
for province in corrections.keys():
    sample = df[df['provincia'] == province].iloc[0] if len(df[df['provincia'] == province]) > 0 else None
    if sample is not None:
        print(f"{province}: ({sample['latitude']}, {sample['longitude']})")
# Out:
# missing: (, )
# Livorno: (43.54673711579884, 10.312234337127085)
